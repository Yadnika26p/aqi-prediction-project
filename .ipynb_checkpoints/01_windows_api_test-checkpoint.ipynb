# %%
print("🌫️ AQI Project - Windows Setup Test")
import sys
print(f"Python version: {sys.version}")
# Out:
# 🌫️ AQI Project - Windows Setup Test
# Python version: 3.13.1 (tags/v3.13.1:0671451, Dec  3 2024, 19:06:28) [MSC v.1942 64 bit (AMD64)]

# %%
import requests
import pandas as pd
print("✅ Libraries loaded")
# Out:
# ✅ Libraries loaded

# %%
# Quick API test
api_key = "your_key_here"  # Paste your key
url = f"http://api.openweathermap.org/data/2.5/air_pollution?lat=28.61&lon=77.20&appid={api_key}"

response = requests.get(url)
print(f"Status: {response.status_code}")

if response.status_code == 200:
    print("🎉 API Working!")
    data = response.json()
    print(data['list'][0]['components'])
else:
    print("Using sample data...")
    # Sample data code here
# Out:
# Status: 401
# Using sample data...
